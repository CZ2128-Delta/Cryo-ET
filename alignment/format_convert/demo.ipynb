# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path

# %%
# customized module
from imodfile_parse_module import imodfile

# %%
# test data path
test_data_path = Path('./test/resources/01.fid')
data_mod = imodfile.IMODFile(test_data_path)

# %%
data_mod.writeContourData('./fiducial_group.json', bin=4)
# Out:
# b'IMODV1.2IMOD-NewModel~\x00\x00\x00(\x00\x00\x00\x01\x00\x00\xf6\x00\x00\x00\x00\x01\x00\x00\x00\x01\x00\x00\x000\x00\x00\x00g\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00?\x80\x00\x00?\x80\x00\x00BH\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03\x00\x00\x00\x80=\x8a=q\xff\xff\xff\xf7\x0e\xee\xce\xca\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00OBJT\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00
# ...

# %%
test_track_data_path = Path('./test/resources/01_track.fid')
track_data_mod = imodfile.IMODFile(test_track_data_path)
with open('./test/resources/01.fid', 'rb') as f:
    data1 = f.read()
with open('./test/resources/01_track.fid', 'rb') as f:
    data2 = f.read()
print(data1)
print(data2)
# Out:
# b'IMODV1.2IMOD-NewModel~\x00\x00\x00(\x00\x00\x00\x01\x00\x00\xf6\x00\x00\x00\x00\x01\x00\x00\x00\x01\x00\x00\x000\x00\x00\x00g\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00?\x80\x00\x00?\x80\x00\x00BH\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03\x00\x00\x00\x80=\x8a=q\xff\xff\xff\xf7\x0e\xee\xce\xca\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00OBJT\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00
# ...

# %%
print(data_mod.conts)
# Out:
# [{'psize': 40, 'flags': 16, 'time': 0, 'surf': 0, 'pts': array([[1.9677500e+03, 2.2552500e+03, 0.0000000e+00],
#        [1.9748788e+03, 2.3296233e+03, 1.0000000e+00],
#        [1.9807777e+03, 2.3894238e+03, 2.0000000e+00],
#        [1.9904595e+03, 2.4500281e+03, 3.0000000e+00],
#        [1.9888610e+03, 2.5069048e+03, 4.0000000e+00],
#        [1.9895623e+03, 2.5712764e+03, 5.0000000e+00],
#        [2.0011223e+03, 2.6179431e+03, 6.0000000e+00],
#        [2.0043221e+03, 2.6668025e+03, 6.9999995e+00],
#        [2.0092560e+03, 2.7155637e+03, 8.0000000e+00],
#        [2.0122646e+03, 2.7561128e+03, 9.0000000e+00],
#        [2.0151080e+03, 2.7968894e+03, 1.0000000e+01],
#        [2.0193827e+03, 2.8362773e+03, 1.0999999e+01],
#        [2.0195679e+03, 2.8727207e+03, 1.2000000e+01],
#        [2.0246359e+03, 2.9125496e+03, 1.3000000e+01],
#        [2.0256318e+03, 2.9322056e+03, 1.3999999e+01],
#        [2.0237880e+03, 2.9551311e+03, 1.4999999e+01],
# ...

# %%
print(track_data_mod.conts)
# print(track_data_mod.objts)
# Out:
# [{'psize': 40, 'flags': 16, 'time': 0, 'surf': 0, 'pts': array([[9.7736450e+02, 2.2500188e+03, 0.0000000e+00],
#        [9.7797980e+02, 2.2793940e+03, 1.0000000e+00],
#        [9.7854370e+02, 2.3072234e+03, 2.0000000e+00],
#        [9.8208142e+02, 2.3334480e+03, 3.0000000e+00],
#        [9.8303198e+02, 2.3596895e+03, 4.0000000e+00],
#        [9.8472559e+02, 2.3832744e+03, 5.0000000e+00],
#        [9.8576166e+02, 2.4058445e+03, 6.0000000e+00],
#        [9.8503027e+02, 2.4246868e+03, 7.0000000e+00],
#        [9.8835236e+02, 2.4405388e+03, 8.0000000e+00],
#        [9.8824243e+02, 2.4542627e+03, 9.0000000e+00],
#        [9.8707690e+02, 2.4678655e+03, 1.0000000e+01],
#        [9.9093750e+02, 2.4777917e+03, 1.1000000e+01],
#        [9.9076190e+02, 2.4865525e+03, 1.2000000e+01],
#        [9.9266040e+02, 2.4924341e+03, 1.3000000e+01],
#        [9.9230109e+02, 2.4998279e+03, 1.4000000e+01],
#        [9.9296002e+02, 2.5052400e+03, 1.5000000e+01],
# ...
